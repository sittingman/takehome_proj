# %% [markdown]
# # Part 3 - Predictive modeling

# %%
import json
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from scipy import stats
from pycaret.classification import *
import seaborn as sns
# %matplotlib inline
# Out:
# C:\Users\sit_k\AppData\Local\Continuum\anaconda3\lib\site-packages\statsmodels\tools\_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm

# %%
# %%html
# <style>
#     table {
#         display: inline-block
#     }
# </style>
# Out:
# <style>
#     table {
#         display: inline-block
#     }
# </style>

# %% [markdown]
# #### Reading Json data into panda dataframe

# %%
f = open('ultimate_data_challenge.json',)
data = json.load(f)
df = pd.json_normalize(data)

# %%
df.head()
# Out:
#              city  trips_in_first_30_days signup_date  avg_rating_of_driver  \
# 0  King's Landing                       4  2014-01-25                   4.7
# 1         Astapor                       0  2014-01-29                   5.0
# 2         Astapor                       3  2014-01-06                   4.3
# 3  King's Landing                       9  2014-01-10                   4.6
# 4      Winterfell                      14  2014-01-27                   4.4
#
#    avg_surge last_trip_date    phone  surge_pct  ultimate_black_user  \
# 0       1.10     2014-06-17   iPhone       15.4                 True
# 1       1.00     2014-05-05  Android        0.0                False
# 2       1.00     2014-01-07   iPhone        0.0                False
# 3       1.14     2014-06-29   iPhone       20.0                 True
# 4       1.19     2014-03-15  Android       11.8                False
#
#    weekday_pct  avg_dist  avg_rating_by_driver
# 0         46.2      3.67                   5.0
# 1         50.0      8.26                   5.0
# 2        100.0      0.77                   5.0
# 3         80.0      2.36                   4.9
# 4         82.4      3.13                   4.9

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50000 entries, 0 to 49999
# Data columns (total 12 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   city                    50000 non-null  object
#  1   trips_in_first_30_days  50000 non-null  int64
#  2   signup_date             50000 non-null  object
#  3   avg_rating_of_driver    41878 non-null  float64
#  4   avg_surge               50000 non-null  float64
#  5   last_trip_date          50000 non-null  object
#  6   phone                   49604 non-null  object
#  7   surge_pct               50000 non-null  float64
#  8   ultimate_black_user     50000 non-null  bool
#  9   weekday_pct             50000 non-null  float64
#  10  avg_dist                50000 non-null  float64
#  11  avg_rating_by_driver    49799 non-null  float64
# dtypes: bool(1), float64(6), int64(1), object(4)
# memory usage: 4.2+ MB

# %% [markdown]
# #### Data Wrangling

# %% [markdown]
# Notice phone attributes have missing values. It could because user using operating system beyond android and iphone (e.g. Window phone, or login using desktop). Fill missing values with "other" for now.

# %%
df['phone'] = df['phone'].fillna('other')

# %% [markdown]
# Signup_date and last_trip_date should be in datatime format

# %%
df['signup_date'] = pd.to_datetime(df['signup_date'], format='%Y-%m-%d')
df['last_trip_date'] = pd.to_datetime(df['last_trip_date'], format='%Y-%m-%d')

# %% [markdown]
# Question did not specify what is the starting point for preceding 30 days. We pick the maximum values under last_trip_date column as the start date, and that is 2014-07-01

# %%
today = df['last_trip_date'].max()
today
# Out:
# Timestamp('2014-07-01 00:00:00')

# %% [markdown]
# **Target creation**
# - subtract all values under last_trip_date by 2014-07-01, convert that into integer
# - if integer values are less than 30, we treat them as 'retained' customers, assign 1 under variable 'active', eles 0

# %%
df['day_since_last'] = (today - df['last_trip_date'])/np.timedelta64(1, 'D')

# %%
df['active'] = (df['day_since_last'] < 30).astype(int)

# %%
df.head()
# Out:
#              city  trips_in_first_30_days signup_date  avg_rating_of_driver  \
# 0  King's Landing                       4  2014-01-25                   4.7
# 1         Astapor                       0  2014-01-29                   5.0
# 2         Astapor                       3  2014-01-06                   4.3
# 3  King's Landing                       9  2014-01-10                   4.6
# 4      Winterfell                      14  2014-01-27                   4.4
#
#    avg_surge last_trip_date    phone  surge_pct  ultimate_black_user  \
# 0       1.10     2014-06-17   iPhone       15.4                 True
# 1       1.00     2014-05-05  Android        0.0                False
# 2       1.00     2014-01-07   iPhone        0.0                False
# 3       1.14     2014-06-29   iPhone       20.0                 True
# 4       1.19     2014-03-15  Android       11.8                False
#
#    weekday_pct  avg_dist  avg_rating_by_driver  day_since_last  active
# 0         46.2      3.67                   5.0            14.0       1
# 1         50.0      8.26                   5.0            57.0       0
# 2        100.0      0.77                   5.0           175.0       0
# 3         80.0      2.36                   4.9             2.0       1
# 4         82.4      3.13                   4.9           108.0       0

# %% [markdown]
# Remove signup_date, last_trip_date, and day_since_last features as they won't be used as features.

# %%
df_1 = df.drop(['signup_date', 'last_trip_date', 'day_since_last'], axis=1)

# %%
df_1.head()
# Out:
#              city  trips_in_first_30_days  avg_rating_of_driver  avg_surge  \
# 0  King's Landing                       4                   4.7       1.10
# 1         Astapor                       0                   5.0       1.00
# 2         Astapor                       3                   4.3       1.00
# 3  King's Landing                       9                   4.6       1.14
# 4      Winterfell                      14                   4.4       1.19
#
#      phone  surge_pct  ultimate_black_user  weekday_pct  avg_dist  \
# 0   iPhone       15.4                 True         46.2      3.67
# 1  Android        0.0                False         50.0      8.26
# 2   iPhone        0.0                False        100.0      0.77
# 3   iPhone       20.0                 True         80.0      2.36
# 4  Android       11.8                False         82.4      3.13
#
#    avg_rating_by_driver  active
# 0                   5.0       1
# 1                   5.0       0
# 2                   5.0       0
# 3                   4.9       1
# 4                   4.9       0

# %%
ave_retain_rate = 1 - df_1['active'].sum()/len(df_1)
print('Overall attrition rate is {:.2%}'.format(ave_retain_rate))
# Out:
# Overall attrition rate is 63.38%

# %% [markdown]
# Baseline model would be to assume all clients are attrited, and the accuracy will be **63.38%**

# %% [markdown]
# #### Exploratory Analysis

# %% [markdown]
# Using 63.38% as benchmark, we want to see which attributes in the dataset will show significant differentiation from the benchmark.

# %%
def form_crosstab(attr):
    """create crosstab dataframe among attribute across active users

    Args:
    attr: attributes in the dataframe

    Returns:
    crosstab table
    """
    table = pd.crosstab(df_1[attr], df_1['active'], values=df_1['active'],
                        aggfunc='count', normalize='index')
    return table

# %%
def bar_plot(data, var):
    """Stack bar chart to show the result of % of active by attribute

    Args:
    data: crosstab table object
    var: attritbute in the dataframe

    Returns:
    stacked bar chart
    """
    data.plot.bar(stacked=True, figsize=(15, 5))
    plt.title('attrition rate by '+var, fontsize=20)
    plt.xlabel(var, fontsize=15)
    plt.ylabel('%', fontsize=15)
    plt.axhline(y=ave_retain_rate, color='red', label='benchmark')
    plt.legend(('benchmark', 'attrited', 'retained'))
    plt.autoscale(enable=True)
    plt.show()

# %%
def area_plot(data, var):
    """Stack area chart to show the result of % of active by attribute

    Args:
    data: crosstab table object
    var: attritbute in the dataframe

    Returns:
    stacked area chart
    """
    data.plot(kind='area', stacked=True, figsize=(15, 5))
    plt.title('attrition rate by '+var, fontsize=20)
    plt.xlabel(var, fontsize=15)
    plt.ylabel('%', fontsize=15)
    plt.axhline(y=ave_retain_rate, color='red', label='benchmark')
    plt.legend(('attrited', 'retained', 'benchmark',))
    plt.autoscale(enable=True)
    plt.show()

# %%
for col in df_1.columns[:-1]:
    if df_1[col].dtype == float:
        area_plot(form_crosstab(col), col)
    else:
        bar_plot(form_crosstab(col), col)

# %% [markdown]
# From the above visualization, the follow attributes appear to be have influence on user attritions
# - city, phone, avg_surge, surge_pct, ultimate_black_user
# - trips_in_first_30_days appear to have inverse linear relationship with attrition from 0-30 trips, but beyond that relationship is unclear. We will keep this attribute for to see if that will help improve the model

# %% [markdown]
# ### Chi Square Test
#
# Testing the significance on the category variable influence to attritions.

# %%
def chi_sq_test(attr):
    """measure p-value of chi_sq test for attributes

    Args:
    attr: attribute that is being test

    Returns:
    p-values, degree of freedom
    """
    table = pd.crosstab(df_1[attr], df_1['active'],
                        values=df_1['active'], aggfunc='count')
    stat, p, dof, expected = stats.chi2_contingency(table[[0, 1]])
    print('attribute tested: {}'.format(attr))
    print('p-value: {:.2f}'.format(p))
    print('degree of freedom: {:.0f}'.format(dof))

# %%
chi_sq_test('city')
# Out:
# attribute tested: city
# p-value: 0.00
# degree of freedom: 2

# %%
chi_sq_test('ultimate_black_user')
# Out:
# attribute tested: ultimate_black_user
# p-value: 0.00
# degree of freedom: 1

# %%
chi_sq_test('phone')
# Out:
# attribute tested: phone
# p-value: 0.00
# degree of freedom: 2

# %% [markdown]
# City, ultimate_black_user, and phone all show dependence to attrition rates.

# %% [markdown]
# ### Setting final dataframe
#
# Per analysis above, the features to be used for machine learning analysis are
# - **city**: city this user signed up in
# - **phone**: primary device for this user
# - **avg_surge**: The average surge multiplier over all of this user’s trips
# - **surge_pct**: the percent of trips taken with surge multiplier > 1
# - **ultimate_black_user**: TRUE if the user took an Ultimate Black in their first 30 days; FALSE otherwise
# - **trips_in_first_30_days**: the number of trips this user took in the first 30 days after signing up

# %%
final_df = df_1[['city', 'phone', 'avg_surge', 'surge_pct',
                 'ultimate_black_user', 'trips_in_first_30_days', 'active']]

# %%
final_df.head()
# Out:
#              city    phone  avg_surge  surge_pct  ultimate_black_user  \
# 0  King's Landing   iPhone       1.10       15.4                 True
# 1         Astapor  Android       1.00        0.0                False
# 2         Astapor   iPhone       1.00        0.0                False
# 3  King's Landing   iPhone       1.14       20.0                 True
# 4      Winterfell  Android       1.19       11.8                False
#
#    trips_in_first_30_days  active
# 0                       4       1
# 1                       0       0
# 2                       3       0
# 3                       9       1
# 4                      14       0

# %% [markdown]
# ### Model Training

# %%
exp = setup(final_df, target='active', train_size=0.8)
# Out:
#
# Setup Succesfully Completed!
# <style  type="text/css" >
# </style><table id="T_441509a2_aa07_11ea_9f7b_3cf0112ace06" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Description</th>        <th class="col_heading level0 col1" >Value</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_441509a2_aa07_11ea_9f7b_3cf0112ace06level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_441509a2_aa07_11ea_9f7b_3cf0112ace06row0_col0" class="data row0 col0" >session_id</td>
#                         <td id="T_441509a2_aa07_11ea_9f7b_3cf0112ace06row0_col1" class="data row0 col1" >518</td>
#             </tr>
#             <tr>
#                         <th id="T_441509a2_aa07_11ea_9f7b_3cf0112ace06level0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_441509a2_aa07_11ea_9f7b_3cf0112ace06row1_col0" class="data row1 col0" >Target Type</td>
#                         <td id="T_441509a2_aa07_11ea_9f7b_3cf0112ace06row1_col1" class="data row1 col1" >Binary</td>
#             </tr>
#             <tr>
#                         <th id="T_441509a2_aa07_11ea_9f7b_3cf0112ace06level0_row2" class="row_heading level0 row2" >2</th>
#                         <td id="T_441509a2_aa07_11ea_9f7b_3cf0112ace06row2_col0" class="data row2 col0" >Label Encoded</td>
#                         <td id="T_441509a2_aa07_11ea_9f7b_3cf0112ace06row2_col1" class="data row2 col1" >None</td>
#             </tr>
#             <tr>
#                         <th id="T_441509a2_aa07_11ea_9f7b_3cf0112ace06level0_row3" class="row_heading level0 row3" >3</th>
#                         <td id="T_441509a2_aa07_11ea_9f7b_3cf0112ace06row3_col0" class="data row3 col0" >Original Data</td>
#                         <td id="T_441509a2_aa07_11ea_9f7b_3cf0112ace06row3_col1" class="data row3 col1" >(50000, 7)</td>
#             </tr>
#             <tr>
#                         <th id="T_441509a2_aa07_11ea_9f7b_3cf0112ace06level0_row4" class="row_heading level0 row4" >4</th>
#                         <td id="T_441509a2_aa07_11ea_9f7b_3cf0112ace06row4_col0" class="data row4 col0" >Missing Values </td>
#                         <td id="T_441509a2_aa07_11ea_9f7b_3cf0112ace06row4_col1" class="data row4 col1" >False</td>
#             </tr>
#             <tr>
#                         <th id="T_441509a2_aa07_11ea_9f7b_3cf0112ace06level0_row5" class="row_heading level0 row5" >5</th>
#                         <td id="T_441509a2_aa07_11ea_9f7b_3cf0112ace06row5_col0" class="data row5 col0" >Numeric Features </td>
#                         <td id="T_441509a2_aa07_11ea_9f7b_3cf0112ace06row5_col1" class="data row5 col1" >3</td>
#             </tr>
#             <tr>
#                         <th id="T_441509a2_aa07_11ea_9f7b_3cf0112ace06level0_row6" class="row_heading level0 row6" >6</th>
#                         <td id="T_441509a2_aa07_11ea_9f7b_3cf0112ace06row6_col0" class="data row6 col0" >Categorical Features </td>
#                         <td id="T_441509a2_aa07_11ea_9f7b_3cf0112ace06row6_col1" class="data row6 col1" >3</td>
#             </tr>
#             <tr>
#                         <th id="T_441509a2_aa07_11ea_9f7b_3cf0112ace06level0_row7" class="row_heading level0 row7" >7</th>
#                         <td id="T_441509a2_aa07_11ea_9f7b_3cf0112ace06row7_col0" class="data row7 col0" >Ordinal Features </td>
#                         <td id="T_441509a2_aa07_11ea_9f7b_3cf0112ace06row7_col1" class="data row7 col1" >False</td>
#             </tr>
#             <tr>
#                         <th id="T_441509a2_aa07_11ea_9f7b_3cf0112ace06level0_row8" class="row_heading level0 row8" >8</th>
#                         <td id="T_441509a2_aa07_11ea_9f7b_3cf0112ace06row8_col0" class="data row8 col0" >High Cardinality Features </td>
#                         <td id="T_441509a2_aa07_11ea_9f7b_3cf0112ace06row8_col1" class="data row8 col1" >False</td>
#             </tr>
#             <tr>
#                         <th id="T_441509a2_aa07_11ea_9f7b_3cf0112ace06level0_row9" class="row_heading level0 row9" >9</th>
#                         <td id="T_441509a2_aa07_11ea_9f7b_3cf0112ace06row9_col0" class="data row9 col0" >High Cardinality Method </td>
#                         <td id="T_441509a2_aa07_11ea_9f7b_3cf0112ace06row9_col1" class="data row9 col1" >None</td>
#             </tr>
#             <tr>
#                         <th id="T_441509a2_aa07_11ea_9f7b_3cf0112ace06level0_row10" class="row_heading level0 row10" >10</th>
#                         <td id="T_441509a2_aa07_11ea_9f7b_3cf0112ace06row10_col0" class="data row10 col0" >Sampled Data</td>
#                         <td id="T_441509a2_aa07_11ea_9f7b_3cf0112ace06row10_col1" class="data row10 col1" >(50000, 7)</td>
#             </tr>
#             <tr>
#                         <th id="T_441509a2_aa07_11ea_9f7b_3cf0112ace06level0_row11" class="row_heading level0 row11" >11</th>
#                         <td id="T_441509a2_aa07_11ea_9f7b_3cf0112ace06row11_col0" class="data row11 col0" >Transformed Train Set</td>
#                         <td id="T_441509a2_aa07_11ea_9f7b_3cf0112ace06row11_col1" class="data row11 col1" >(40000, 10)</td>
#             </tr>
#             <tr>
#                         <th id="T_441509a2_aa07_11ea_9f7b_3cf0112ace06level0_row12" class="row_heading level0 row12" >12</th>
#                         <td id="T_441509a2_aa07_11ea_9f7b_3cf0112ace06row12_col0" class="data row12 col0" >Transformed Test Set</td>
#                         <td id="T_441509a2_aa07_11ea_9f7b_3cf0112ace06row12_col1" class="data row12 col1" >(10000, 10)</td>
#             </tr>
#             <tr>
#                         <th id="T_441509a2_aa07_11ea_9f7b_3cf0112ace06level0_row13" class="row_heading level0 row13" >13</th>
#                         <td id="T_441509a2_aa07_11ea_9f7b_3cf0112ace06row13_col0" class="data row13 col0" >Numeric Imputer </td>
#                         <td id="T_441509a2_aa07_11ea_9f7b_3cf0112ace06row13_col1" class="data row13 col1" >mean</td>
#             </tr>
#             <tr>
#                         <th id="T_441509a2_aa07_11ea_9f7b_3cf0112ace06level0_row14" class="row_heading level0 row14" >14</th>
#                         <td id="T_441509a2_aa07_11ea_9f7b_3cf0112ace06row14_col0" class="data row14 col0" >Categorical Imputer </td>
#                         <td id="T_441509a2_aa07_11ea_9f7b_3cf0112ace06row14_col1" class="data row14 col1" >constant</td>
#             </tr>
#             <tr>
#                         <th id="T_441509a2_aa07_11ea_9f7b_3cf0112ace06level0_row15" class="row_heading level0 row15" >15</th>
#                         <td id="T_441509a2_aa07_11ea_9f7b_3cf0112ace06row15_col0" class="data row15 col0" >Normalize </td>
#                         <td id="T_441509a2_aa07_11ea_9f7b_3cf0112ace06row15_col1" class="data row15 col1" >False</td>
#             </tr>
#             <tr>
#                         <th id="T_441509a2_aa07_11ea_9f7b_3cf0112ace06level0_row16" class="row_heading level0 row16" >16</th>
#                         <td id="T_441509a2_aa07_11ea_9f7b_3cf0112ace06row16_col0" class="data row16 col0" >Normalize Method </td>
#                         <td id="T_441509a2_aa07_11ea_9f7b_3cf0112ace06row16_col1" class="data row16 col1" >None</td>
#             </tr>
#             <tr>
#                         <th id="T_441509a2_aa07_11ea_9f7b_3cf0112ace06level0_row17" class="row_heading level0 row17" >17</th>
#                         <td id="T_441509a2_aa07_11ea_9f7b_3cf0112ace06row17_col0" class="data row17 col0" >Transformation </td>
#                         <td id="T_441509a2_aa07_11ea_9f7b_3cf0112ace06row17_col1" class="data row17 col1" >False</td>
#             </tr>
#             <tr>
#                         <th id="T_441509a2_aa07_11ea_9f7b_3cf0112ace06level0_row18" class="row_heading level0 row18" >18</th>
#                         <td id="T_441509a2_aa07_11ea_9f7b_3cf0112ace06row18_col0" class="data row18 col0" >Transformation Method </td>
#                         <td id="T_441509a2_aa07_11ea_9f7b_3cf0112ace06row18_col1" class="data row18 col1" >None</td>
#             </tr>

# %% [markdown]
# ### Model Performance metrics consideration
#
# Ultimate's priority is to understand what drive users to stay using the services. Given that the company may invest on program changes based on the results, we want the model has the best performance on correctly separating out retained vs attrited users. In that case, AUC would be the best metric to evaluate model performance

# %%
compare_models(fold=6, sort='AUC')
# Out:
# <style  type="text/css" >
#     #T_96e92468_aa07_11ea_a0e0_3cf0112ace06 th {
#           text-align: left;
#     }    #T_96e92468_aa07_11ea_a0e0_3cf0112ace06row0_col0 {
#             text-align:  left;
#         }    #T_96e92468_aa07_11ea_a0e0_3cf0112ace06row0_col1 {
#             background-color:  yellow;
#             text-align:  left;
#         }    #T_96e92468_aa07_11ea_a0e0_3cf0112ace06row0_col2 {
#             background-color:  yellow;
#             text-align:  left;
#         }    #T_96e92468_aa07_11ea_a0e0_3cf0112ace06row0_col3 {
#             : ;
#             text-align:  left;
#         }    #T_96e92468_aa07_11ea_a0e0_3cf0112ace06row0_col4 {
#             : ;
#             text-align:  left;
#         }    #T_96e92468_aa07_11ea_a0e0_3cf0112ace06row0_col5 {
#             background-color:  yellow;
#             text-align:  left;
#         }    #T_96e92468_aa07_11ea_a0e0_3cf0112ace06row0_col6 {
#             background-color:  yellow;
#             text-align:  left;
#         }    #T_96e92468_aa07_11ea_a0e0_3cf0112ace06row1_col0 {
#             text-align:  left;
#         }    #T_96e92468_aa07_11ea_a0e0_3cf0112ace06row1_col1 {
#             : ;
#             text-align:  left;
#         }    #T_96e92468_aa07_11ea_a0e0_3cf0112ace06row1_col2 {
#             : ;
#             text-align:  left;
#         }    #T_96e92468_aa07_11ea_a0e0_3cf0112ace06row1_col3 {
#             : ;
#             text-align:  left;
#         }    #T_96e92468_aa07_11ea_a0e0_3cf0112ace06row1_col4 {
#             background-color:  yellow;
#             text-align:  left;
#         }    #T_96e92468_aa07_11ea_a0e0_3cf0112ace06row1_col5 {
#             : ;
#             text-align:  left;
#         }    #T_96e92468_aa07_11ea_a0e0_3cf0112ace06row1_col6 {
#             : ;
#             text-align:  left;
#         }    #T_96e92468_aa07_11ea_a0e0_3cf0112ace06row2_col0 {
#             text-align:  left;
#         }    #T_96e92468_aa07_11ea_a0e0_3cf0112ace06row2_col1 {
#             : ;
#             text-align:  left;
#         }    #T_96e92468_aa07_11ea_a0e0_3cf0112ace06row2_col2 {
#             : ;
#             text-align:  left;
#         }    #T_96e92468_aa07_11ea_a0e0_3cf0112ace06row2_col3 {
#             : ;
#             text-align:  left;
#         }    #T_96e92468_aa07_11ea_a0e0_3cf0112ace06row2_col4 {
#             : ;
#             text-align:  left;
#         }    #T_96e92468_aa07_11ea_a0e0_3cf0112ace06row2_col5 {
#             : ;
#             text-align:  left;
#         }    #T_96e92468_aa07_11ea_a0e0_3cf0112ace06row2_col6 {
#             : ;
#             text-align:  left;
#         }    #T_96e92468_aa07_11ea_a0e0_3cf0112ace06row3_col0 {
#             text-align:  left;
#         }    #T_96e92468_aa07_11ea_a0e0_3cf0112ace06row3_col1 {
#             : ;
#             text-align:  left;
#         }    #T_96e92468_aa07_11ea_a0e0_3cf0112ace06row3_col2 {
#             : ;
#             text-align:  left;
#         }    #T_96e92468_aa07_11ea_a0e0_3cf0112ace06row3_col3 {
#             : ;
#             text-align:  left;
#         }    #T_96e92468_aa07_11ea_a0e0_3cf0112ace06row3_col4 {
#             : ;
#             text-align:  left;
#         }    #T_96e92468_aa07_11ea_a0e0_3cf0112ace06row3_col5 {
#             : ;
#             text-align:  left;
#         }    #T_96e92468_aa07_11ea_a0e0_3cf0112ace06row3_col6 {
#             : ;
#             text-align:  left;
#         }    #T_96e92468_aa07_11ea_a0e0_3cf0112ace06row4_col0 {
#             text-align:  left;
#         }    #T_96e92468_aa07_11ea_a0e0_3cf0112ace06row4_col1 {
#             : ;
#             text-align:  left;
#         }    #T_96e92468_aa07_11ea_a0e0_3cf0112ace06row4_col2 {
#             : ;
#             text-align:  left;
#         }    #T_96e92468_aa07_11ea_a0e0_3cf0112ace06row4_col3 {
#             : ;
#             text-align:  left;
#         }    #T_96e92468_aa07_11ea_a0e0_3cf0112ace06row4_col4 {
#             : ;
#             text-align:  left;
#         }    #T_96e92468_aa07_11ea_a0e0_3cf0112ace06row4_col5 {
#             : ;
#             text-align:  left;
#         }    #T_96e92468_aa07_11ea_a0e0_3cf0112ace06row4_col6 {
#             : ;
#             text-align:  left;
#         }    #T_96e92468_aa07_11ea_a0e0_3cf0112ace06row5_col0 {
#             text-align:  left;
#         }    #T_96e92468_aa07_11ea_a0e0_3cf0112ace06row5_col1 {
#             : ;
#             text-align:  left;
#         }    #T_96e92468_aa07_11ea_a0e0_3cf0112ace06row5_col2 {
#             : ;
#             text-align:  left;
#         }    #T_96e92468_aa07_11ea_a0e0_3cf0112ace06row5_col3 {
#             : ;
#             text-align:  left;
#         }    #T_96e92468_aa07_11ea_a0e0_3cf0112ace06row5_col4 {
#             : ;
#             text-align:  left;
#         }    #T_96e92468_aa07_11ea_a0e0_3cf0112ace06row5_col5 {
#             : ;
#             text-align:  left;
#         }    #T_96e92468_aa07_11ea_a0e0_3cf0112ace06row5_col6 {
#             : ;
#             text-align:  left;
#         }    #T_96e92468_aa07_11ea_a0e0_3cf0112ace06row6_col0 {
#             text-align:  left;
#         }    #T_96e92468_aa07_11ea_a0e0_3cf0112ace06row6_col1 {
#             : ;
#             text-align:  left;
#         }    #T_96e92468_aa07_11ea_a0e0_3cf0112ace06row6_col2 {
#             : ;
#             text-align:  left;
#         }    #T_96e92468_aa07_11ea_a0e0_3cf0112ace06row6_col3 {
#             : ;
#             text-align:  left;
#         }    #T_96e92468_aa07_11ea_a0e0_3cf0112ace06row6_col4 {
#             : ;
#             text-align:  left;
#         }    #T_96e92468_aa07_11ea_a0e0_3cf0112ace06row6_col5 {
#             : ;
#             text-align:  left;
#         }    #T_96e92468_aa07_11ea_a0e0_3cf0112ace06row6_col6 {
#             : ;
#             text-align:  left;
#         }    #T_96e92468_aa07_11ea_a0e0_3cf0112ace06row7_col0 {
#             text-align:  left;
#         }    #T_96e92468_aa07_11ea_a0e0_3cf0112ace06row7_col1 {
#             : ;
#             text-align:  left;
#         }    #T_96e92468_aa07_11ea_a0e0_3cf0112ace06row7_col2 {
#             : ;
#             text-align:  left;
#         }    #T_96e92468_aa07_11ea_a0e0_3cf0112ace06row7_col3 {
#             : ;
#             text-align:  left;
#         }    #T_96e92468_aa07_11ea_a0e0_3cf0112ace06row7_col4 {
#             : ;
#             text-align:  left;
#         }    #T_96e92468_aa07_11ea_a0e0_3cf0112ace06row7_col5 {
#             : ;
#             text-align:  left;
#         }    #T_96e92468_aa07_11ea_a0e0_3cf0112ace06row7_col6 {
#             : ;
#             text-align:  left;
#         }    #T_96e92468_aa07_11ea_a0e0_3cf0112ace06row8_col0 {
#             text-align:  left;
#         }    #T_96e92468_aa07_11ea_a0e0_3cf0112ace06row8_col1 {
#             : ;
#             text-align:  left;
#         }    #T_96e92468_aa07_11ea_a0e0_3cf0112ace06row8_col2 {
#             : ;
#             text-align:  left;
#         }    #T_96e92468_aa07_11ea_a0e0_3cf0112ace06row8_col3 {
#             : ;
#             text-align:  left;
#         }    #T_96e92468_aa07_11ea_a0e0_3cf0112ace06row8_col4 {
#             : ;
#             text-align:  left;
#         }    #T_96e92468_aa07_11ea_a0e0_3cf0112ace06row8_col5 {
#             : ;
#             text-align:  left;
#         }    #T_96e92468_aa07_11ea_a0e0_3cf0112ace06row8_col6 {
#             : ;
#             text-align:  left;
#         }    #T_96e92468_aa07_11ea_a0e0_3cf0112ace06row9_col0 {
#             text-align:  left;
#         }    #T_96e92468_aa07_11ea_a0e0_3cf0112ace06row9_col1 {
#             : ;
#             text-align:  left;
#         }    #T_96e92468_aa07_11ea_a0e0_3cf0112ace06row9_col2 {
#             : ;
#             text-align:  left;
#         }    #T_96e92468_aa07_11ea_a0e0_3cf0112ace06row9_col3 {
#             : ;
#             text-align:  left;
#         }    #T_96e92468_aa07_11ea_a0e0_3cf0112ace06row9_col4 {
#             : ;
#             text-align:  left;
#         }    #T_96e92468_aa07_11ea_a0e0_3cf0112ace06row9_col5 {
#             : ;
#             text-align:  left;
#         }    #T_96e92468_aa07_11ea_a0e0_3cf0112ace06row9_col6 {
#             : ;
#             text-align:  left;
#         }    #T_96e92468_aa07_11ea_a0e0_3cf0112ace06row10_col0 {
#             text-align:  left;
#         }    #T_96e92468_aa07_11ea_a0e0_3cf0112ace06row10_col1 {
#             : ;

# %% [markdown]
# Based on initial model performance, we choose the top models that have the highest AUC (Catboost and Light Gradient Boosting Machine), then we will choose one tree base model Random Forecast for performance comparison.

# %%
cat = create_model('catboost', fold=4)
# Out:
#       Accuracy     AUC  Recall   Prec.      F1   Kappa
# 0       0.7621  0.8129  0.5456  0.7365  0.6268  0.4578
# 1       0.7728  0.8212  0.5745  0.7466  0.6494  0.4855
# 2       0.7696  0.8180  0.5699  0.7411  0.6443  0.4782
# 3       0.7637  0.8178  0.5508  0.7375  0.6306  0.4622
# Mean    0.7670  0.8175  0.5602  0.7404  0.6378  0.4709
# SD      0.0043  0.0030  0.0123  0.0040  0.0093  0.0113

# %%
interpret_model(cat)

# %%
lightgbm = create_model('lightgbm', fold=4)
# Out:
#       Accuracy     AUC  Recall   Prec.      F1   Kappa
# 0       0.7628  0.8128  0.5467  0.7377  0.6280  0.4595
# 1       0.7727  0.8210  0.5691  0.7499  0.6471  0.4841
# 2       0.7700  0.8178  0.5702  0.7420  0.6448  0.4791
# 3       0.7652  0.8174  0.5511  0.7414  0.6322  0.4652
# Mean    0.7677  0.8173  0.5593  0.7427  0.6380  0.4719
# SD      0.0039  0.0029  0.0105  0.0045  0.0081  0.0100

# %%
interpret_model(lightgbm)

# %%
plot_model(lightgbm)

# %%
rfc = create_model('rf', fold=4)
# Out:
#       Accuracy     AUC  Recall   Prec.      F1   Kappa
# 0       0.7494  0.7909  0.5126  0.7225  0.5997  0.4249
# 1       0.7589  0.7985  0.5434  0.7292  0.6228  0.4511
# 2       0.7550  0.7973  0.5369  0.7228  0.6161  0.4419
# 3       0.7515  0.7950  0.5208  0.7232  0.6055  0.4310
# Mean    0.7537  0.7954  0.5284  0.7244  0.6110  0.4372
# SD      0.0036  0.0029  0.0123  0.0028  0.0090  0.0101

# %%
interpret_model(rfc)

# %%
plot_model(rfc)

# %% [markdown]
# #### Performance Summary
#
# |Model | Accuracy | AUC |
# | --- | --- | --- |
# | Baseline | 63.38% | NA |
# | Random Forest | 75.38% | 0.7982 |
# | Catboost | 76.90% | **0.8204** |
# | Lightgbm | 76.79%| 0.8194 |
#
# Model performance is at the 75%-77% range, which is ~12-13% better than baseline model.
# <br>
# Catboost has the best performance in this analysis. Catboost is particular good at handling category variables. Its good performance in this case could be attributed to strong categorical features.

# %% [markdown]
# ### Insights:
#
# - All models suggested that users who took more trips with multiplier > 1 are likely to use the services long term. Perhaps they view the service as expensive as they don't get to enjoy the base rate of the service often. Ultimate may consider providing some promotion to that users segment. Promotion examples could be bundle trips purchases, or award them points which they can use in other purchases. After all, those are the users who pay higher price/trip, and they have long term client value if we can retain them.
# - King's landing city client tend to be more loyal than the other two cities. Good to understand if it is demand or supply driven. If it is demand driven, Ultimate could consider adjusting the rate in the other cities to boost loyalty. If it is supply related, Ultimate can extend the recruiting efforts in the other two cities
# - It is surprising to see that phone pay a role in loyalty. Recommend Ulitmate software engineer team to revisit Android app user experience.
